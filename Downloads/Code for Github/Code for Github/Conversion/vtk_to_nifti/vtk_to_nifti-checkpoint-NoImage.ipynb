# %% [markdown]
# # Convert VTK surface segmentation files to NIfTI image masks

# %%
import os.path
import pandas as pd
import sys
import vtk

import vtk2image_NoImage

# %% [markdown]
# ## Setup the input data

# %%
#df_valid = pd.read_csv("/Users/Tom/Desktop/Deep-Learning/conversion/image_path.csv")
df_valid = pd.read_csv("/Volumes/William's Passport SSD/Yale_Data/paths/vtk_to_nifti_path.csv")
df_valid
# Out:
#                                              SEGM_PATH ACCESSION_ID
# 0    /Volumes/William's Passport SSD/Yale_Data/data...          t_1
# 1    /Volumes/William's Passport SSD/Yale_Data/data...          t_2
# 2    /Volumes/William's Passport SSD/Yale_Data/data...          t_3
# 3    /Volumes/William's Passport SSD/Yale_Data/data...          t_4
# 4    /Volumes/William's Passport SSD/Yale_Data/data...          t_5
# ..                                                 ...          ...
# 579  /Volumes/William's Passport SSD/Yale_Data/data...         a_45
# 580  /Volumes/William's Passport SSD/Yale_Data/data...         a_46
# 581  /Volumes/William's Passport SSD/Yale_Data/data...         a_47
# 582  /Volumes/William's Passport SSD/Yale_Data/data...         a_48
# 583  /Volumes/William's Passport SSD/Yale_Data/data...         a_49
#
# [584 rows x 2 columns]

# %%
df_valid['ACCESSION_ID'] = df_valid['ACCESSION_ID'].apply(str)

# %% [markdown]
# ## Convert the segms to masks

# %%
OUTPUT_PATH = "/Volumes/William's Passport SSD/Yale_Data/data"

# %%
count = 0

for idx, row in df_valid.iterrows():
    name = row['SEGM_PATH'].split('_')[-1]
    output_path_id = os.path.join(OUTPUT_PATH,row['ACCESSION_ID'])
    if not os.path.exists(output_path_id):
        try:
            os.mkdir(output_path_id)
        except :
            print('ERROR: Could not create dir: %s' % output_path_id)            
        else:
            print('Created new output dir: %s' % output_path_id)
    SUBFOLDER = os.path.split(os.path.split(row['SEGM_PATH'])[0])[-1]
    output_path = os.path.join(output_path_id, SUBFOLDER)
    if not os.path.exists(output_path):
        try:
            os.mkdir(output_path)
        except :
            print('ERROR: Could not create dir: %s' % output_path)            
        else:
            print('Created new output dir: %s' % output_path)
    
    input_file_name = os.path.split(row['SEGM_PATH'])[-1]
    input_file_root = os.path.splitext(input_file_name)[0]
    output_file_name = os.path.join(output_path,'%s.nii.gz' % (input_file_root))
    print('Creating mask file: %s' % output_file_name)
    
    if not os.path.exists(output_file_name):

        surf_reader = vtk.vtkPolyDataReader()
        surf_reader.SetFileName(row['SEGM_PATH'])
        surf_reader.Update()

        vtk_surface = vtk.vtkPolyData()
        vtk_surface.ShallowCopy(surf_reader.GetOutput())
        print('VTK file has %d points' % (vtk_surface.GetNumberOfPoints()))

        #image_reader = vtk.vtkNIFTIImageReader()
        #image_reader.SetFileName(row['IMAGE_PATH'])
        #image_reader.Update()

        #vtk_image = vtk.vtkImageData()
        #vtk_image.ShallowCopy(image_reader.GetOutput())
        #print('NIfTI file has dims = %s' % str(vtk_image.GetDimensions()))

        image_mask = vtk2image_NoImage.convert(vtk_surface)

        writer = vtk.vtkNIFTIImageWriter()
        writer.SetInputData(image_mask)
        writer.SetFileName(output_file_name)
        writer.Update()
        
        count += 1
    else:
        print('File already exists, skipping...')
        
print('Finished performing %d conversions this run' % count)
# Out:
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/t
nii.gz
# VTK file has 0 points
# NIfTI file has dims = (-4, -4, -4)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_6/pre/p6_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_7/pre/p7_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_8/pre/p8_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_9/pre/p9_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_10/pre/p10_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_11/pre/p11_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_12/pre/p12_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_13/pre/p13_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_14/pre/p14_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_15/pre/p15_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_16/pre/p16_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_17/pre/p17_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_18/pre/p18_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_19/pre/p19_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_20/pre/p20_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_21/pre/p21_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_22/pre/p22_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_23/pre/p23_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_24/pre/p24_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_25/pre/p25_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_26/pre/p26_total_pre.nii.gz
# VTK file has 0 points
# NIfTI file has dims = (-4, -4, -4)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_27/pre/p27_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_28/pre/p28_total_pre.nii.gz
# VTK file has 0 points
# NIfTI file has dims = (-4, -4, -4)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_29/pre/p29_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_30/pre/p30_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_31/pre/p31_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_32/pre/p32_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_33/pre/p33_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_34/pre/p34_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_35/pre/p35_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_36/pre/p36_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_37/pre/p37_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_38/pre/p38_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_39/pre/p39_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_40/pre/p40_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_41/pre/p41_total_pre.nii.gz
# VTK file has 0 points
# NIfTI file has dims = (-4, -4, -4)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_42/pre/p42_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_43/pre/p43_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_44/pre/p44_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_45/pre/p45_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_46/pre/p46_total_pre.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_1/post/p1_total_post.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_2/post/p2_total_post.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_3/post/p3_total_post.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_4/post/p4_total_post.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_5/post/p5_total_post.nii.gz
# VTK file has 0 points
# NIfTI file has dims = (-4, -4, -4)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_6/post/p6_total_post.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_7/post/p7_total_post.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_8/post/p8_total_post.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_9/post/p9_total_post.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_10/post/p10_total_post.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_11/post/p11_total_post.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_12/post/p12_total_post.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_13/post/p13_total_post.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_14/post/p14_total_post.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_15/post/p15_total_post.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_16/post/p16_total_post.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_17/post/p17_total_post.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_18/post/p18_total_post.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_19/post/p19_total_post.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_20/post/p20_total_post.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_21/post/p21_total_post.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_22/post/p22_total_post.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_23/post/p23_total_post.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_24/post/p24_total_post.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_25/post/p25_total_post.nii.gz
# File already exists, skipping...
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_26/post/p26_total_post.nii.gz
# VTK file has 0 points
# NIfTI file has dims = (-4, -4, -4)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/m_27/post/p27_total_post.nii.gz
# File already exists, skipping...
# ...
# Created new output dir: /Volumes/William's Passport SSD/Yale_Data/data/a_7/post
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_7/post/liver_left_mdacc_p_7.nii.gz
# VTK file has 0 points
# NIfTI file has dims = (-4, -4, -4)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_8/post/liver_left_mdacc_p_8.nii.gz
# VTK file has 1626 points
# NIfTI file has dims = (307, 240, 178)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_9/post/liver_left_mdacc_p_9.nii.gz
# VTK file has 7280 points
# NIfTI file has dims = (308, 183, 336)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_10/post/liver_left_mdacc_p_10.nii.gz
# VTK file has 4026 points
# NIfTI file has dims = (265, 241, 151)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_11/post/liver_left_mdacc_p_11.nii.gz
# VTK file has 2392 points
# NIfTI file has dims = (401, 190, 262)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_12/post/liver_left_mdacc_p_12.nii.gz
# VTK file has 2322 points
# NIfTI file has dims = (319, 178, 263)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_13/post/liver_left_mdacc_p_13.nii.gz
# VTK file has 6890 points
# NIfTI file has dims = (199, 228, 87)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_14/post/liver_left_mdacc_p_14.nii.gz
# VTK file has 2488 points
# NIfTI file has dims = (338, 200, 203)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_15/post/liver_left_mdacc_p_15.nii.gz
# VTK file has 5353 points
# NIfTI file has dims = (320, 233, 260)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_16/post/liver_left_mdacc_p_16.nii.gz
# VTK file has 5823 points
# NIfTI file has dims = (362, 180, 213)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_17/post/liver_left_mdacc_p_17.nii.gz
# VTK file has 5844 points
# NIfTI file has dims = (426, 303, 187)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_18/post/liver_left_mdacc_p_18.nii.gz
# VTK file has 2098 points
# NIfTI file has dims = (261, 182, 203)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_19/post/liver_left_mdacc_p_19.nii.gz
# VTK file has 5979 points
# NIfTI file has dims = (318, 163, 229)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_20/post/liver_left_mdacc_p_20.nii.gz
# VTK file has 3448 points
# NIfTI file has dims = (313, 242, 176)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_21/post/liver_left_mdacc_p_21.nii.gz
# VTK file has 5544 points
# NIfTI file has dims = (358, 281, 248)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_22/post/liver_left_mdacc_p_22.nii.gz
# VTK file has 1298 points
# NIfTI file has dims = (217, 237, 171)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_23/post/liver_left_mdacc_p_23.nii.gz
# VTK file has 1668 points
# NIfTI file has dims = (255, 192, 265)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_24/post/liver_left_mdacc_p_24.nii.gz
# VTK file has 2260 points
# NIfTI file has dims = (218, 207, 297)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_25/post/liver_left_mdacc_p_25.nii.gz
# VTK file has 1840 points
# NIfTI file has dims = (364, 215, 184)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_26/post/liver_left_mdacc_p_26.nii.gz
# VTK file has 3392 points
# NIfTI file has dims = (292, 177, 248)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_27/post/liver_left_mdacc_p_27.nii.gz
# VTK file has 7226 points
# NIfTI file has dims = (327, 200, 236)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_28/post/liver_left_mdacc_p_28.nii.gz
# VTK file has 2098 points
# NIfTI file has dims = (271, 161, 278)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_29/post/liver_left_mdacc_p_29.nii.gz
# VTK file has 5402 points
# NIfTI file has dims = (232, 187, 217)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_30/post/liver_left_mdacc_p_30.nii.gz
# VTK file has 6472 points
# NIfTI file has dims = (384, 254, 178)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_31/post/liver_left_mdacc_p_31.nii.gz
# VTK file has 3906 points
# NIfTI file has dims = (358, 437, 177)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_32/post/liver_left_mdacc_p_32.nii.gz
# VTK file has 6153 points
# NIfTI file has dims = (367, 274, 184)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_33/post/liver_left_mdacc_p_33.nii.gz
# VTK file has 4895 points
# NIfTI file has dims = (378, 263, 282)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_34/post/liver_left_mdacc_p_34.nii.gz
# VTK file has 2656 points
# NIfTI file has dims = (282, 335, 232)
# Created new output dir: /Volumes/William's Passport SSD/Yale_Data/data/a_35/post
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_35/post/liver_left_mdacc_p_35.nii.gz
# VTK file has 0 points
# NIfTI file has dims = (-4, -4, -4)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_36/post/liver_left_mdacc_p_36.nii.gz
# VTK file has 1660 points
# NIfTI file has dims = (249, 328, 201)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_37/post/liver_left_mdacc_p_37.nii.gz
# VTK file has 3008 points
# NIfTI file has dims = (328, 315, 251)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_38/post/liver_left_mdacc_p_38.nii.gz
# VTK file has 1572 points
# NIfTI file has dims = (236, 247, 219)
# Created new output dir: /Volumes/William's Passport SSD/Yale_Data/data/a_39/post
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_39/post/liver_left_mdacc_p_39.nii.gz
# VTK file has 0 points
# NIfTI file has dims = (-4, -4, -4)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_40/post/liver_left_mdacc_p_40.nii.gz
# VTK file has 2974 points
# NIfTI file has dims = (386, 234, 205)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_41/post/liver_left_mdacc_p_41.nii.gz
# VTK file has 1784 points
# NIfTI file has dims = (260, 273, 248)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_42/post/liver_left_mdacc_p_42.nii.gz
# VTK file has 1602 points
# NIfTI file has dims = (210, 228, 180)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_43/post/liver_left_mdacc_p_43.nii.gz
# VTK file has 2436 points
# NIfTI file has dims = (265, 265, 209)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_44/post/liver_left_mdacc_p_44.nii.gz
# VTK file has 3090 points
# NIfTI file has dims = (296, 187, 274)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_45/post/liver_left_mdacc_p_45.nii.gz
# VTK file has 2444 points
# NIfTI file has dims = (356, 217, 251)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_46/post/liver_left_mdacc_p_46.nii.gz
# VTK file has 2796 points
# NIfTI file has dims = (282, 218, 233)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_47/post/liver_left_mdacc_p_47.nii.gz
# VTK file has 1998 points
# NIfTI file has dims = (364, 195, 229)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_48/post/liver_left_mdacc_p_48.nii.gz
# VTK file has 3450 points
# NIfTI file has dims = (307, 184, 156)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_49/post/liver_left_mdacc_p_49.nii.gz
# VTK file has 6341 points
# NIfTI file has dims = (326, 214, 267)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_0/post/liver_total_mdacc_p_0.nii.gz
# VTK file has 5648 points
# NIfTI file has dims = (416, 391, 428)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_1/post/liver_total_mdacc_p_1.nii.gz
# VTK file has 5838 points
# NIfTI file has dims = (407, 336, 321)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_2/post/liver_total_mdacc_p_2.nii.gz
# VTK file has 5725 points
# NIfTI file has dims = (434, 363, 313)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_3/post/liver_total_mdacc_p_3.nii.gz
# VTK file has 6183 points
# NIfTI file has dims = (483, 475, 329)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_4/post/liver_total_mdacc_p_4.nii.gz
# VTK file has 0 points
# NIfTI file has dims = (-4, -4, -4)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_5/post/liver_total_mdacc_p_5.nii.gz
# VTK file has 4220 points
# NIfTI file has dims = (342, 290, 304)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_6/post/liver_total_mdacc_p_6.nii.gz
# VTK file has 5658 points
# NIfTI file has dims = (336, 317, 276)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_7/post/liver_total_mdacc_p_7.nii.gz
# VTK file has 0 points
# NIfTI file has dims = (-4, -4, -4)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_8/post/liver_total_mdacc_p_8.nii.gz
# VTK file has 5438 points
# NIfTI file has dims = (392, 362, 346)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_9/post/liver_total_mdacc_p_9.nii.gz
# VTK file has 5686 points
# NIfTI file has dims = (379, 276, 337)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_10/post/liver_total_mdacc_p_10.nii.gz
# VTK file has 4612 points
# NIfTI file has dims = (370, 350, 280)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_11/post/liver_total_mdacc_p_11.nii.gz
# VTK file has 3742 points
# NIfTI file has dims = (433, 319, 330)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_12/post/liver_total_mdacc_p_12.nii.gz
# VTK file has 11202 points
# NIfTI file has dims = (400, 323, 379)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_13/post/liver_total_mdacc_p_13.nii.gz
# VTK file has 5366 points
# NIfTI file has dims = (423, 359, 404)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_14/post/liver_total_mdacc_p_14.nii.gz
# VTK file has 5782 points
# NIfTI file has dims = (402, 326, 313)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_15/post/liver_total_mdacc_p_15.nii.gz
# VTK file has 5827 points
# NIfTI file has dims = (358, 363, 335)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_16/post/liver_total_mdacc_p_16.nii.gz
# VTK file has 4980 points
# NIfTI file has dims = (413, 309, 238)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_17/post/liver_total_mdacc_p_17.nii.gz
# VTK file has 5669 points
# NIfTI file has dims = (531, 400, 263)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_18/post/liver_total_mdacc_p_18.nii.gz
# VTK file has 5804 points
# NIfTI file has dims = (441, 298, 336)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_19/post/liver_total_mdacc_p_19.nii.gz
# VTK file has 6359 points
# NIfTI file has dims = (355, 293, 286)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_20/post/liver_total_mdacc_p_20.nii.gz
# VTK file has 6240 points
# NIfTI file has dims = (400, 321, 256)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_21/post/liver_total_mdacc_p_21.nii.gz
# VTK file has 5354 points
# NIfTI file has dims = (386, 401, 358)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_22/post/liver_total_mdacc_p_22.nii.gz
# VTK file has 6378 points
# NIfTI file has dims = (390, 386, 379)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_23/post/liver_total_mdacc_p_23.nii.gz
# VTK file has 3140 points
# NIfTI file has dims = (404, 286, 283)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_24/post/liver_total_mdacc_p_24.nii.gz
# VTK file has 5910 points
# NIfTI file has dims = (369, 322, 306)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_25/post/liver_total_mdacc_p_25.nii.gz
# VTK file has 3424 points
# NIfTI file has dims = (422, 364, 269)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_26/post/liver_total_mdacc_p_26.nii.gz
# VTK file has 5582 points
# NIfTI file has dims = (325, 307, 339)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_27/post/liver_total_mdacc_p_27.nii.gz
# VTK file has 3668 points
# NIfTI file has dims = (372, 322, 245)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_28/post/liver_total_mdacc_p_28.nii.gz
# VTK file has 5332 points
# NIfTI file has dims = (483, 312, 334)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_29/post/liver_total_mdacc_p_29.nii.gz
# VTK file has 5516 points
# NIfTI file has dims = (384, 333, 349)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_30/post/liver_total_mdacc_p_30.nii.gz
# VTK file has 6284 points
# NIfTI file has dims = (475, 378, 255)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_31/post/liver_total_mdacc_p_31.nii.gz
# VTK file has 6454 points
# NIfTI file has dims = (468, 453, 272)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_32/post/liver_total_mdacc_p_32.nii.gz
# VTK file has 5902 points
# NIfTI file has dims = (466, 409, 327)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_33/post/liver_total_mdacc_p_33.nii.gz
# VTK file has 6100 points
# NIfTI file has dims = (409, 372, 327)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_34/post/liver_total_mdacc_p_34.nii.gz
# VTK file has 5668 points
# NIfTI file has dims = (459, 422, 284)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_35/post/liver_total_mdacc_p_35.nii.gz
# VTK file has 0 points
# NIfTI file has dims = (-4, -4, -4)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_36/post/liver_total_mdacc_p_36.nii.gz
# VTK file has 3844 points
# NIfTI file has dims = (389, 518, 256)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_37/post/liver_total_mdacc_p_37.nii.gz
# VTK file has 5336 points
# NIfTI file has dims = (368, 374, 279)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_38/post/liver_total_mdacc_p_38.nii.gz
# VTK file has 4958 points
# NIfTI file has dims = (415, 400, 287)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_39/post/liver_total_mdacc_p_39.nii.gz
# VTK file has 0 points
# NIfTI file has dims = (-4, -4, -4)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_40/post/liver_total_mdacc_p_40.nii.gz
# VTK file has 6776 points
# NIfTI file has dims = (452, 391, 280)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_41/post/liver_total_mdacc_p_41.nii.gz
# VTK file has 5824 points
# NIfTI file has dims = (449, 374, 345)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_42/post/liver_total_mdacc_p_42.nii.gz
# VTK file has 5318 points
# NIfTI file has dims = (378, 355, 301)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_43/post/liver_total_mdacc_p_43.nii.gz
# VTK file has 6470 points
# NIfTI file has dims = (439, 391, 271)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_44/post/liver_total_mdacc_p_44.nii.gz
# VTK file has 5550 points
# NIfTI file has dims = (377, 331, 278)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_45/post/liver_total_mdacc_p_45.nii.gz
# VTK file has 5824 points
# NIfTI file has dims = (449, 342, 339)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_46/post/liver_total_mdacc_p_46.nii.gz
# VTK file has 5214 points
# NIfTI file has dims = (324, 290, 264)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_47/post/liver_total_mdacc_p_47.nii.gz
# VTK file has 4664 points
# NIfTI file has dims = (438, 367, 324)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_48/post/liver_total_mdacc_p_48.nii.gz
# VTK file has 5148 points
# NIfTI file has dims = (495, 300, 288)
# Creating mask file: /Volumes/William's Passport SSD/Yale_Data/data/a_49/post/liver_total_mdacc_p_49.nii.gz
# VTK file has 6251 points
# NIfTI file has dims = (375, 325, 335)
# Finished performing 230 conversions this run
